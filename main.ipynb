# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load dataset
df = pd.read_csv("perfume.csv")
df.head()
# Out:
#            brand                                  instagram_link  followers  \
# 0      Alchemist  https://www.instagram.com/alchemist.fragrance/      17800
# 1  Alien Objects         https://www.instagram.com/alienobjects/      15700
# 2  ALT Perfumery        https://www.instagram.com/alt.perfumery/       6528
# 3         Aromes            https://www.instagram.com/aromes.id/      15700
# 4      Ataraksia         https://www.instagram.com/ataraksia.id/       8019
#
#      year             variant  \
# 0  2022.0         Powder Room
# 1  2019.0                XOXO
# 2  2021.0     Moroccan Sunset
# 3  2022.0          Crazy Sexy
# 4  2021.0  Societeit Harmonie
#
#                                         variant_link concentration  size  \
# 0  https://shopee.co.id/alchemist.fragrance/17137...           EDP    50
# 1      https://shopee.co.id/alienobjects/14283008217           EDP    50
# 2      https://shopee.co.id/altperfumery/12639590547           EDP    50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   brand           82 non-null     object
#  1   instagram_link  82 non-null     object
#  2   followers       82 non-null     int64
#  3   year            81 non-null     float64
#  4   variant         82 non-null     object
#  5   variant_link    82 non-null     object
#  6   concentration   82 non-null     object
#  7   size            82 non-null     int64
#  8   price           82 non-null     object
#  9   price_per_ml    82 non-null     object
#  10  top_notes1      82 non-null     object
#  11  top_notes2      76 non-null     object
#  12  top_notes3      55 non-null     object
#  13  top_notes4      21 non-null     object
#  14  top_notes5      9 non-null      object
#  15  top_notes6      5 non-null      object
#  16  mid_notes1      75 non-null     object
# ...

# %%
# drop duplicate data
duplicate = df[df.duplicated()]
print(duplicate.shape)

df = df.drop_duplicates()
# Out:
# (0, 30)

# %%
df.count()
# Out:
# brand             82
# instagram_link    82
# followers         82
# year              81
# variant           82
# variant_link      82
# concentration     82
# size              82
# price             82
# price_per_ml      82
# top_notes1        82
# top_notes2        76
# top_notes3        55
# top_notes4        21
# top_notes5         9
# top_notes6         5
# mid_notes1        75
# mid_notes2        69
# mid_notes3        51
# mid_notes4        18
# mid_notes5         8
# mid_notes6         3
# mid_notes7         2
# base_notes1       71
# base_notes2       67
# base_notes3       50
# base_notes4       25
# base_notes5       10
# base_notes6        7
# base_notes7        2
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# brand              0
# instagram_link     0
# followers          0
# year               1
# variant            0
# variant_link       0
# concentration      0
# size               0
# price              0
# price_per_ml       0
# top_notes1         0
# top_notes2         6
# top_notes3        27
# top_notes4        61
# top_notes5        73
# top_notes6        77
# mid_notes1         7
# mid_notes2        13
# mid_notes3        31
# mid_notes4        64
# mid_notes5        74
# mid_notes6        79
# mid_notes7        80
# base_notes1       11
# base_notes2       15
# base_notes3       32
# base_notes4       57
# base_notes5       72
# base_notes6       75
# base_notes7       80
# dtype: int64

# %%
# displaying data with barplot
few = df.head(20)
plt.bar(few["brand"], few["followers"], color="blue", width=0.5)
plt.xlabel("Brand Parfum Indonesia")
plt.ylabel("Pengikut Media Sosial")
plt.title("Data Jumlah Pengikut Media Sosial Brand Parfum Indonesia")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# displaying data with pieplot
few = df.head(20)
plt.pie(few["followers"], labels=few["brand"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8d3e9bc1c0>,
# ...
#  [Text(1.097251790494087, 0.07770783909954315, 'Alchemist'),
#   Text(1.0772426194843152, 0.22259456140384706, 'Alien Objects'),
#   Text(1.0534191899623573, 0.3167143985028964, 'ALT Perfumery'),
#   Text(1.0213894512411243, 0.4083669782112103, 'Aromes'),
#   Text(0.9784432914682543, 0.5026417465559032, 'Ataraksia'),
#   Text(0.9594967367024411, 0.5379275158024236, 'avantglossy'),
#   Text(0.9553469729444414, 0.5452633870762762, 'Avicenna'),
#   Text(0.9527087669677261, 0.5498599870356409, 'Azwary Perfume'),
#   Text(0.9395737033944777, 0.5720150836206911, "Bali Surfer's Perfume"),
#   Text(0.8751676089051964, 0.6663945200278596, 'Black Friday'),
#   Text(0.8026792837827357, 0.7521342748379671, 'Brishka'),
#   Text(0.671122807024898, 0.8715470026860409, 'CARESO'),
#   Text(0.26818470904151887, 1.066806899975959, 'Carl & Claire'),
#   Text(-0.907927751486023, -0.6210210931051655, 'De.Claires'),
# ...

# %%
# displaying data with scatterplot
few = df.head(20)
plt.scatter(few["followers"], few["price_per_ml"])
plt.xlabel("Followers")
plt.ylabel("Price per mL")
plt.title("Scatter Plot of Followers vs. Price per mL")
plt.show()

# %%
# display followers outliers
outl = plt.figure(figsize=(12,4))
outl.add_subplot(1,2,1)
df['followers'].plot(kind='kde')
outl.add_subplot(1,2,2)
plt.boxplot(df['followers'])
plt.show()
